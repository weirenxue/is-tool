# %%
import requests
from bs4 import BeautifulSoup

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"}
headers["Cookie"] = "__AntiXsrfToken=da018ace0cf94c8e9b9fe12e83afe1f3; ASP.NET_SessionId=bi5woopcqonjsukxalikbz2b; UserName=0000A104; .ASPXAUTH=835BF71AD8FAADB75C1F2E3757B63A0F94722355E821ED77BE9D837739980B0603B37CFDD87C59B75D31506D96ED854E23D05485746EB79E0F796251C46CD3C61D5B382C20018D49D59BA8D539C57F0BFD16BC792862B5F8E4D6288E2CD46EFC4D0464B18075E06F1811DB4D94A93919DEFD4EA3"
url = "https://teach.cloud.ncnu.edu.tw/choose_project"
response = requests.get(url, headers = headers)
soup = BeautifulSoup(response.text, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <title>
#    國中小課程與教學計畫填報系統
#   </title>
#   <link href="/css/main.css" rel="stylesheet"/>
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet"/>
#   <link href="/new_css/plugins/animate.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/new_css/gl-style.css" rel="stylesheet"/>
#   <link href="/new_css/other-panel.css" rel="stylesheet"/>
#   <link href="Scripts/SmartWizard/src/css/smart_wizard.css" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css" integrity="sha384-JcKb8q3iqJ61gNV9KGb8thSsNjpSL0n8PARn9HuZOnIxN0hoP+VmmDGMN5t9UJ0Z" rel="stylesheet"/>
#   <style>
# ...
